# %% [markdown]
# W1A1

# %%
a = 7
b = 5
c = a - b
print(c)
# Out:
# 2

# %% [markdown]
# W1A2

# %%
city = "Hà Nội"
year = 2025
print("Thành phố: ", city, "-Năm: ", year)
# Out:
# Thành phố:  Hà Nội -Năm:  2025

# %% [markdown]
# W1A3

# %%
n = int(input())
t = 0
for i in range(1, n-1, 2):
    t += 1
print(t)
# Out:
# 1

# %%
a =4
b = 5
a,b = b, a
print(a,b)
# Out:
# 5 4
